# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
#parameters
n1 = 30 #samples in dataset 1
n2 = 40 #samples in dataset 2
mu1 = 1 #population mean in dataset 1
mu2 = 2 #population mean in dataset 2

#generate the data
data1 = mu1 + np.random.randn(n1)
data2 = mu2 + np.random.randn(n2)

#plot
plt.plot(np.zeros(n1), data1, 'ro', markerfacecolor='w', markersize=14)
plt.plot(np.ones(n2), data2, 'bs', markerfacecolor='w', markersize=14)
plt.xlim([-1,2])
plt.xticks([0,1], labels=['Group 1', 'Group 2'])
plt.show()

# %% [markdown]
# ##Is this difference in data significant?

# %%
#t test via stats

# _ind = independent samples
t, p = stats.ttest_ind(data1, data2)
print(t)
print(p)
# Out:
# -3.6813854224889675
# 0.0004604968671605456

# %% [markdown]
# Results:
# -3.6813854224889675
# 0.0004604968671605456
# This tells us that group two, p, has a larger mean than group 1.

# %%
#show t test results in plot to help better visualise the data distribution.
fig = plt.figure(figsize=(10, 4))
plt.rcParams.update({'font.size': 12})

plt.plot(0+np.random.randn(n1)/15, data1, 'ro', markerfacecolor='w', markersize=14)
plt.plot(1+np.random.randn(n2)/15, data2, 'bs', markerfacecolor='w', markersize=14)
plt.xlim([-1,2])
plt.xticks([0,1], labels=['Group 1', 'Group 2'])
# Out:
# ([<matplotlib.axis.XTick at 0x7b386452b1d0>,
# ...
#  [Text(0, 0, 'Group 1'), Text(1, 0, 'Group 2')])
